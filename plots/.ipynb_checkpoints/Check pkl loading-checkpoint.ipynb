# %%
import joblib

# %%
dir_in_output = '/home/tristan/mesmer/output/'
file = '2_emu_innovations_fix.pkl'

emu_res = joblib.load(dir_in_output+file)

# %%
emu_res
# Out:
# {0: array([[[ 9.72599404e-03, -9.26149512e-02, -1.26222891e-01, ...,
#            1.23068345e+00,  1.01082174e+00,  6.47480462e-01],
#          [ 3.87560636e-01,  1.11822898e-01, -4.57302637e-02, ...,
#            6.47600065e-01,  4.36081899e-01,  1.62103309e-01],
#          [ 1.68446729e-01,  2.16421908e-01,  1.86039257e-01, ...,
#           -1.45557561e+00, -9.43697725e-01, -3.33389320e-01],
#          ...,
#          [-2.87541536e-01, -2.11637010e-01, -8.74389525e-02, ...,
#            9.00685856e-02,  1.45857251e-01,  2.12007786e-01],
#          [ 1.05893483e+00,  8.49651523e-01,  6.42296829e-01, ...,
#            7.51647373e-01,  8.92746321e-01,  1.09367723e+00],
#          [ 6.22834129e-01,  7.25231420e-01,  7.24033708e-01, ...,
#            1.51006569e-01,  2.65775193e-01,  4.33993917e-01]],
#
#         [[-8.06471463e-02, -1.96594781e-01, -2.83393707e-01, ...,
#            9.51901641e-01,  8.97885991e-01,  8.52049433e-01],
# ...
